# %%
import math
from array import array
import reprlib

class Vector:
    typecode = 'd'
    def __init__(self, components):
        self._components = array(self.typecode, components)

    def __iter__(self):
        return iter(self._components)

    def __repr__(self):
        components = reprlib.repr(self._components)
        components = components[components.find('['):-1]
        return f'Vector({components})'

    def __str__(self): 
        return str(tuple(self)) #NOTE: because Vector is iterable so it can be built into a tuple

    def __bytes__(self):
        return bytes[ord(self.typecode)] + bytes[self._components]

    def __eq__(self, value):
        return tuple(self) == tuple(value)

    def __abs__(self):
        return math.hypot(*self) # iterable so unpacking works!

    def __bool__(self):
        return bool(abs(self))

    @classmethod
    def frombytes(cls, octets):
        typecode = chr(octets[0])
        memv = memoryview(octets[1:]).cast(typecode)
        return cls(memv)

    # Duck Typing: when it behaves like a duck it IS a duck!
    def __len__(self):
        return len(self._components)

    # def __getitem__(self, key): # iteration!
    #     if isinstance(key, slice):


v1 = Vector([1, 2])
v1
# Out:
# Vector([1.0, 2.0])

# %%
v2 = Vector((1,2,3))
v2
# Out:
# Vector([1.0, 2.0, 3.0])

# %%
v3 = Vector(range(4))
v3
# Out:
# Vector([0.0, 1.0, 2.0, 3.0])

# %%
for i in v3:
    print(i)
# Out:
# 0.0
# 1.0
# 2.0
# 3.0

# %%
print(v3)
# Out:
# Vector([0.0, 1.0, 2.0, 3.0])

# %%
#### How Slice Works
class MySeq:
    def __getitem__(self, index):
        return index

s = MySeq()
s[1]
# Out:
# 1

# %%
s[1:3]
# Out:
# slice(1, 3, None)

# %%
s[1:4:2]
# Out:
# slice(1, 4, 2)

# %%
s[1:4:2, 9] # it receives a tuple!
# Out:
# (slice(1, 4, 2), 9)

# %%
s[1:4:2, 7:9]
# Out:
# (slice(1, 4, 2), slice(7, 9, None))

# %%
slice
# Out:
# slice

# %%
dir(slice)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'indices',
#  'start',
#  'step',
#  'stop']

# %%
288800 - 89000
# Out:
# 199800

# %%
445800 - 89000 - 199800
# Out:
# 157000

# %%
93800 - 57800
# Out:
# 36000

# %%
6927*2/
